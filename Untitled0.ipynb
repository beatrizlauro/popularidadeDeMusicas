# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Valor Real")
plt.ylabel("Valor Previsto")
plt.title("Real vs Previsto — RandomForest")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

importances = model.feature_importances_
features = X.columns

importance_df = pd.DataFrame({
    "feature": features,
    "importance": importances
}).sort_values("importance", ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(importance_df["feature"], importance_df["importance"])
plt.title("Importância das Variáveis — RandomForest")
plt.gca().invert_yaxis()
plt.show()

# %%
df.columns
df = df.drop(columns=["artists", "track_name"], errors="ignore")
df = df.drop(columns=["unnamed0", "track_genre"], errors="ignore")
df["key"].unique()
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["key"] = le.fit_transform(df["key"])
df.select_dtypes(include="object").columns
X = df.drop("popularity", axis=1)
y = df["popularity"]

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error, r2_score

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))
# Out:
# MAE: 0.10660336917786487
# R²: 0.5241225034409626

# %%
df.dtypes
# Out:
# unnamed0              int64
# artists              object
# track_name           object
# popularity          float64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# duration_s          float64
# mode_1                 bool
# genre_encoded         int64
# dtype: object

# %%
import pandas as pd

df = pd.read_csv("spotify_tracks_transformed.csv")
df.head()
# Out:
#    unnamed0                 artists                  track_name  popularity  \
# 0         0             Gen Hoshino                      Comedy        0.73
# 1         1            Ben Woodward            Ghost - Acoustic        0.55
# 2         2  Ingrid Michaelson;ZAYN              To Begin Again        0.57
# 3         3            Kina Grannis  Can't Help Falling In Love        0.71
# 4         4        Chord Overstreet                     Hold On        0.82
#
#    explicit  danceability  energy  key  loudness  speechiness  acousticness  \
# 0     False      0.686294  0.4610    1  0.791392     0.148187      0.032329
# 1     False      0.426396  0.1660    1  0.597377     0.079067      0.927711
# 2     False      0.444670  0.3590    0  0.736123     0.057720      0.210843
# 3     False      0.270051  0.0596    0  0.573701     0.037617      0.908635
# 4     False      0.627411  0.4430    2  0.737103     0.054508      0.470884
#
# ...

# %%
# 1. Clonar o repositório
# !git clone https://github.com/beatrizlauro/popularidadeDeMusicas.git

# 2. Ir para pasta do projeto
import os
os.chdir("popularidadeDeMusicas")

# 3. (Se houver) instalar dependências
# !pip install -r requirements.txt

# 4. Executar ETL / limpeza
# !python etl_spotify.py

# 5. Executar análise exploratória
# !python eda.py

# 6. Executar modelagem / treino /previsões
# !python main.py
# ou
# !python modelagem.py

# 7. Ver resultados, gerar gráficos, avaliar modelos etc.
# Out:
# Cloning into 'popularidadeDeMusicas'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 50 (delta 6), reused 47 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 18.96 MiB | 16.72 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/popularidadeDeMusicas/popularidadeDeMusicas/etl_spotify.py:58: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
# !git clone https://github.com/beatrizlauro/popularidadeDeMusicas.git
# Out:
# fatal: destination path 'popularidadeDeMusicas' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/popularidadeDeMusicas") # Changed to use the absolute path
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# arquivoOriginal  main.py       README.md
# eda.py		 modelagem.py  results
# etl_spotify.py	 __pycache__   spotify_tracks_transformed.csv
